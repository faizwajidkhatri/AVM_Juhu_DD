# %% [markdown]
# importing pandas

# %%
import pandas as pd

# %% [markdown]
# Pandas Important Functions

# %%
data=[['Amit',35],['Nikita',24],['Clara',40]]
df=pd.DataFrame(data,columns=['Name','Age'])
print(df)

df.columns=["First_name","Age"]
df
# Out:
#      Name  Age
# 0    Amit   35
# 1  Nikita   24
# 2   Clara   40
#   First_name  Age
# 0       Amit   35
# 1     Nikita   24
# 2      Clara   40

# %%
data={'Name':['Amit','Nimisha','Nikita'],'Age':[20,24,21]}
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0     Amit   20
# 1  Nimisha   24
# 2   Nikita   21

# %%
df['Newcol']=[6,12,30]
print(df)
# Out:
#       Name  Age  Newcol
# 0     Amit   20       6
# 1  Nimisha   24      12
# 2   Nikita   21      30

# %%
df["Revised_col"]=df["Newcol"]*2
print(df)
# Out:
#       Name  Age  Newcol  Revised_col
# 0     Amit   20       6           12
# 1  Nimisha   24      12           24
# 2   Nikita   21      30           60

# %%
del df["Newcol"]     
df
# Out:
#       Name  Age  Revised_col
# 0     Amit   20           12
# 1  Nimisha   24           24
# 2   Nikita   21           60

# %% [markdown]
# Importing a file in Pandas

# %%
data = pd.read_csv(r'C:\\Users\\khatr\\OneDrive\\Desktop\\Heart.csv',header = 0, index_col = 0)

# %%
data
# Out:
#          age  gender  height  weight  ap_hi  ap_lo dental_plaque  cholesterol  \
# id
# 0      18393       2     168    62.0    110     80           Nil            1
# 1      20228       1     156    85.0    140     90         Heavy            3
# 2      18857       1     165    64.0    130     70         Heavy            3
# 3      17623       2     169    82.0    150    100       Slight             1
# 4      17474       1     156    56.0    100     60           Nil            1
# ...      ...     ...     ...     ...    ...    ...           ...          ...
# 99993  19240       2     168    76.0    120     80       Slight             1
# 99995  22601       1     158   126.0    140     90     Moderate             2
# 99996  19066       2     183   105.0    180     90         Heavy            3
# 99998  22431       1     163    72.0    135     80     Moderate             1
# 99999  20540       1     170    72.0    120     80       Slight             2
#
# ...

# %% [markdown]
# Visualization (EDA)

# %%
data = pd.read_csv(r'C:\\Users\\khatr\\OneDrive\\Desktop\\fish_dataset.csv')

# %%
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
# Using the describe we will try and gain more insights of our data:

#for datatypes
print(data.dtypes)

#for dimensions of the given data
print(data.shape)

#for descriptive statistics of the data 
print(data.describe(include="all"))
# Out:
# Species     object
# Weight     float64
# Length1    float64
# Length2    float64
# Length3    float64
# Height     float64
# Width      float64
# dtype: object
# (159, 7)
#        Species       Weight     Length1     Length2     Length3      Height  \
# count      159   159.000000  159.000000  159.000000  159.000000  159.000000
# unique       7          NaN         NaN         NaN         NaN         NaN
# top      Perch          NaN         NaN         NaN         NaN         NaN
# freq        56          NaN         NaN         NaN         NaN         NaN
# mean       NaN   398.326415   26.247170   28.415723   31.227044    8.970994
# std        NaN   357.978317    9.996441   10.716328   11.610246    4.286208
# min        NaN     0.000000    7.500000    8.400000    8.800000    1.728400
# 25%        NaN   120.000000   19.050000   21.000000   23.150000    5.944800
# 50%        NaN   273.000000   25.200000   27.300000   29.400000    7.786000
# ...

# %%
data.isnull().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
species_count=data['Species'].value_counts()
print(species_count)
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
sns.countplot(x='Species',data=data,palette="Set1")

#Rotate x-labels
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Bream'),
#   Text(1, 0, 'Roach'),
#   Text(2, 0, 'Whitefish'),
#   Text(3, 0, 'Parkki'),
#   Text(4, 0, 'Perch'),
#   Text(5, 0, 'Pike'),
#   Text(6, 0, 'Smelt')])

# %%
corr = data.corr()
sns.heatmap(corr, annot=True, square=True)
plt.yticks(rotation=0)
sns.set(rc = {'figure.figsize':(150,80)}) #run commands
plt.show()
